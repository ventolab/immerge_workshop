# %% [markdown]
# # 1. Setup

# %%
import os, sys
from pathlib import Path

IN_COLAB = "google.colab" in sys.modules

if IN_COLAB:
    
    from google.colab import drive
    drive.mount('/content/drive')

    course_dir = Path("/content/drive/MyDrive/immerge_workshop")
    
    if not course_dir.exists():
        print("First time setup - cloning the course repo into your Drive (may take a minute)...")
        # !git clone --quiet https://github.com/ventolab/immerge_workshop.git "{course_dir}"
    else:
        print("Repo already in your Drive.")

    # %cd {course_dir}

else:
    course_dir = Path("/nfs/team292/projects/immerge_workshop/")
    os.chdir(course_dir)

data_dir    = course_dir / "data"
results_dir = course_dir / "results" / "00-preprocessing"
data_dir.mkdir(parents=True, exist_ok=True)
results_dir.mkdir(parents=True, exist_ok=True)

print(f"Colab: {IN_COLAB} | working dir: {os.getcwd()}")
# Out:
# hello

# %% [markdown]
# # 1.1 Downloading data

# %%
if IN_COLAB:
    # !wget -q -nc -O "{data_dir}/wang_f_2020.h5ad" https://drive.google.com/file/d/1-KeP4_XDW3dWL_I3CQTsPpWryQx2pVkP/view?usp=sharing
    # !wget -q -nc -O "{data_dir}/burns_f_2026.h5ad" https://drive.google.com/file/d/124UWP4xA2CQJOfMBXPr_hk5hv_0oK091/view?usp=share_link
